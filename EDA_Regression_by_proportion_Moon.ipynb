# %%
import pandas as pd

# %%
data = pd.read_csv("Life Expectancy Data.csv")

# %%
data
# Out:
#           Country  Year      Status  Adult Mortality  infant deaths  Alcohol
# 0     Afghanistan  2015  Developing            263.0             62     0.01  \
# 1     Afghanistan  2014  Developing            271.0             64     0.01
# 2     Afghanistan  2013  Developing            268.0             66     0.01
# 3     Afghanistan  2012  Developing            272.0             69     0.01
# 4     Afghanistan  2011  Developing            275.0             71     0.01
# ...           ...   ...         ...              ...            ...      ...
# 2933     Zimbabwe  2004  Developing            723.0             27     4.36
# 2934     Zimbabwe  2003  Developing            715.0             26     4.06
# 2935     Zimbabwe  2002  Developing             73.0             25     4.43
# 2936     Zimbabwe  2001  Developing            686.0             25     1.72
# 2937     Zimbabwe  2000  Developing            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI   ...
# 0                  71.279624         65.0      1154   19.1  ...  \
# 1                  73.523582         62.0       492   18.6  ...
# 2                  73.219243         64.0       430   18.1  ...
# 3                  78.184215         67.0      2787   17.6  ...
# 4                   7.097109         68.0      3013   17.2  ...
# ...                      ...          ...       ...    ...  ...
# 2933                0.000000         68.0        31   27.1  ...
# 2934                0.000000          7.0       998   26.7  ...
# 2935                0.000000         73.0       304   26.3  ...
# 2936                0.000000         76.0       529   25.9  ...
# 2937                0.000000         79.0      1483   25.5  ...
#
#       Total expenditure  Diphtheria    HIV/AIDS         GDP  Population
# 0                  8.16         65.0        0.1  584.259210  33736494.0  \
# 1                  8.18         62.0        0.1  612.696514    327582.0
# 2                  8.13         64.0        0.1  631.744976  31731688.0
# 3                  8.52         67.0        0.1  669.959000   3696958.0
# 4                  7.87         68.0        0.1   63.537231   2978599.0
# ...                 ...          ...        ...         ...         ...
# 2933               7.13         65.0       33.6  454.366654  12777511.0
# 2934               6.52         68.0       36.7  453.351155  12633897.0
# 2935               6.53         71.0       39.8   57.348340    125525.0
# 2936               6.16         75.0       42.1  548.587312  12366165.0
# 2937               7.10         78.0       43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years
# 0                      17.2                 17.3  \
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 2933                    9.4                  9.4
# 2934                    9.8                  9.9
# 2935                    1.2                  1.3
# 2936                    1.6                  1.7
# 2937                   11.0                 11.2
#
#       Income composition of resources  Schooling  Life expectancy
# 0                               0.479       10.1              65.0
# 1                               0.476       10.0              59.9
# 2                               0.470        9.9              59.9
# 3                               0.463        9.8              59.5
# 4                               0.454        9.5              59.2
# ...                               ...        ...               ...
# 2933                            0.407        9.2              44.3
# 2934                            0.418        9.5              44.5
# 2935                            0.427       10.0              44.8
# 2936                            0.427        9.8              45.3
# 2937                            0.434        9.8              46.0
#
# [2938 rows x 22 columns]

# %% [markdown]
# EDA (Exploary Data Analysis)

# %%
print("Number of rows =", len(data))
# Out:
# Number of rows = 2938

# %%
# find if there are null values
data.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# drop null values

data2 = data.dropna()

len(data2)
# Out:
# 1649

# %%
df_encoded = pd.get_dummies(data2, columns=['Status'])
# One-hot encode nominal variable 'Status'

# %%
df_encoded.to_csv("Life_Expectancy_preprocessed.csv")
# Save preprocessed csv files

# %%
df = pd.read_csv("Life_Expectancy_preprocessed.csv")
df = df.iloc[:, 1:]

df
# Out:
#           Country  Year  Adult Mortality  infant deaths  Alcohol
# 0     Afghanistan  2015              263             62     0.01  \
# 1     Afghanistan  2014              271             64     0.01
# 2     Afghanistan  2013              268             66     0.01
# 3     Afghanistan  2012              272             69     0.01
# 4     Afghanistan  2011              275             71     0.01
# ...           ...   ...              ...            ...      ...
# 1644     Zimbabwe  2004              723             27     4.36
# 1645     Zimbabwe  2003              715             26     4.06
# 1646     Zimbabwe  2002               73             25     4.43
# 1647     Zimbabwe  2001              686             25     1.72
# 1648     Zimbabwe  2000              665             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles    BMI
# 0                  71.279624           65      1154   19.1  \
# 1                  73.523582           62       492   18.6
# 2                  73.219243           64       430   18.1
# 3                  78.184215           67      2787   17.6
# 4                   7.097109           68      3013   17.2
# ...                      ...          ...       ...    ...
# 1644                0.000000           68        31   27.1
# 1645                0.000000            7       998   26.7
# 1646                0.000000           73       304   26.3
# 1647                0.000000           76       529   25.9
# 1648                0.000000           79      1483   25.5
#
#       under-five deaths   ...   HIV/AIDS         GDP  Population
# 0                     83  ...        0.1  584.259210  33736494.0  \
# 1                     86  ...        0.1  612.696514    327582.0
# 2                     89  ...        0.1  631.744976  31731688.0
# 3                     93  ...        0.1  669.959000   3696958.0
# 4                     97  ...        0.1   63.537231   2978599.0
# ...                  ...  ...        ...         ...         ...
# 1644                  42  ...       33.6  454.366654  12777511.0
# 1645                  41  ...       36.7  453.351155  12633897.0
# 1646                  40  ...       39.8   57.348340    125525.0
# 1647                  39  ...       42.1  548.587312  12366165.0
# 1648                  39  ...       43.5  547.358878  12222251.0
#
#        thinness  1-19 years   thinness 5-9 years
# 0                      17.2                 17.3  \
# 1                      17.5                 17.5
# 2                      17.7                 17.7
# 3                      17.9                 18.0
# 4                      18.2                 18.2
# ...                     ...                  ...
# 1644                    9.4                  9.4
# 1645                    9.8                  9.9
# 1646                    1.2                  1.3
# 1647                    1.6                  1.7
# 1648                   11.0                 11.2
#
#       Income composition of resources  Schooling  Status_Developed
# 0                               0.479       10.1             False  \
# 1                               0.476       10.0             False
# 2                               0.470        9.9             False
# 3                               0.463        9.8             False
# 4                               0.454        9.5             False
# ...                               ...        ...               ...
# 1644                            0.407        9.2             False
# 1645                            0.418        9.5             False
# 1646                            0.427       10.0             False
# 1647                            0.427        9.8             False
# 1648                            0.434        9.8             False
#
#       Status_Developing  Life expectancy
# 0                  True              65.0
# 1                  True              59.9
# 2                  True              59.9
# 3                  True              59.5
# 4                  True              59.2
# ...                 ...               ...
# 1644               True              44.3
# 1645               True              44.5
# 1646               True              44.8
# 1647               True              45.3
# 1648               True              46.0
#
# [1649 rows x 23 columns]

# %%
# corelation
import matplotlib.pyplot as plt
import seaborn as sns

colormap = plt.cm.PuBu
plt.figure(figsize=(12, 10))
plt.title("Pearson Correlation of Features", y = 1.05, size = 15)
sns.heatmap(df.iloc[:, 1:].corr(), linewidths = 0.1, vmax = 1.0,
           square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 8})
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %%
correlation_matrix = df.iloc[:, 1:].corr()

# Extract values whose correlation exceeds threshold(ex: 0.5)
target_column = 'Life expectancy '
threshold = 0.5
columns_above_threshold = correlation_matrix.index[abs(correlation_matrix[target_column]) > threshold]

# print result
print("\nVariables whose correlation with the target variable exceeds {}:".format(threshold))
print(columns_above_threshold)
# Out:
# Variables whose correlation with the target variable exceeds 0.5:
# Index(['Adult Mortality', ' BMI ', ' HIV/AIDS',
#        'Income composition of resources', 'Schooling', 'Life expectancy '],
#       dtype='object')

# %% [markdown]
# Regression

# %%
columns_above_threshold = list(columns_above_threshold)
columns_above_threshold.remove('Life expectancy ')
# remove target value from list

# %%
X = df[columns_above_threshold]
y = df.iloc[:, -1]
y = y.values.reshape(-1, 1)
X.head()
# chosen variables only
# divide dataset into X(independent) and y(target)
# Out:
#    Adult Mortality   BMI    HIV/AIDS  Income composition of resources
# 0              263   19.1        0.1                            0.479  \
# 1              271   18.6        0.1                            0.476
# 2              268   18.1        0.1                            0.470
# 3              272   17.6        0.1                            0.463
# 4              275   17.2        0.1                            0.454
#
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5

# %%
y
# Out:
# array([[65. ],
#        [59.9],
#        [59.9],
#        ...,
#        [44.8],
#        [45.3],
#        [46. ]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error


# Save model performance for different ratios
test_ratios = np.arange(0.1, 1.0, 0.1)  # ratios (from 0.1 to 0.9, 0.1 interval)
r2_scores = []
rmse_list = []

for test_ratio in test_ratios:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_ratio, random_state=42)
    
    # train model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # evaluate model
    y_pred = model.predict(X_test)
    score = r2_score(y_test, y_pred)
    r2_scores.append(score)    # save score in the list
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse_list.append(rmse)     # save rmse in the list

# %%
# draw a graph
plt.figure(figsize=(10, 6))
plt.plot(test_ratios, r2_scores, marker='o', linestyle='-')
plt.title('Model Performance vs. Test Set Ratio')
plt.xlabel('Test Set Ratio')
plt.ylabel('R2 score')
plt.grid(True)
plt.show()

# %%
# graph
plt.figure(figsize=(10, 6))
plt.plot(test_ratios, rmse_list, marker='o', linestyle='-')
plt.title('Loss value vs. Test Set Ratio')
plt.xlabel('Test Set Ratio')
plt.ylabel('RMSE')
plt.grid(True)
plt.show()

# %% [markdown]
# The model performs best at a test set ratio of 0.3 to 0.6.
# I expected more than 0.9 but not as high as I expected.
# And when it comes to error, it grdually increases slightly.
#
# This is because underfitting occurs when there are few training sets, and overfitting occurs when there are too many training sets, making it difficult to predict test sets.
#
# Generally, the proportion of training sets is often 0.6 or 0.7, but in this case 0.7 looks best when comparing performance and error.
# What do you guys think?
